# %%
from Geometry3D import *

# %%
pa = Point(1,2,3)
pb = Point([2,4,3])
o = origin()
l = Line(pa,pb)
p = Plane(o,pa,pb)

# %%
a = Point(1,2,1)
c = Point(-1,-1,1)
d = Point(1,-1,1)
e = Point(1,1,-1)
h = Point(1,-1,-1)
s = Segment(a,c)

# %%
r = Renderer()
r.add((s,'g',1))
r.add((o,'r',3))
r.show()
